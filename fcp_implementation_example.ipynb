# %%
# setp environment

# %%
# !git clone https://github.com/Jayaos/flow_cp
# %cd /content/Tpro/
# !pwd

# %%
from run_fcp import *
from fcp.config import *
from fcp.utils.reporting import summarize_fcp_results

# %%
fcp_config = FCPConfig(dataset_dir="./data/wind/lstm_2d/wind_LSTM_repeat5_dataset.pkl", 
                      dataset_config_dir="./data/wind/lstm_2d/wind_LSTM_dataset_config.pkl",
                      saving_dir="./results/wind/lstm_2d/", 
                      vf_layer_type="concatlinear", 
                      hidden_dims=[32, 32, 32, 32], 
                      activation=torch.nn.Softplus(), 
                      initial_gaussian_distribution_cov_scale=1,
                      null_condition_prob=0.05,
                      batch_size=4,
                      learning_rate=0.0005,
                      max_epoch=50,
                      additional_training_epoch=0,
                      past_resid_as_feature=True,
                      early_stop=4)

# %%
encoder_config = TransformerEncoderConfig(32, 2, 128, 4, 0.1, 50)

# %%
run_fcp(fcp_config, encoder_config, device="cuda")
# Out:
# use Transformer as an encoder
# training flow...
#   0%|                                                                                           | 0/79 [00:00<?, ?it/s]C:\Users\jayao\Desktop\python_projects\virtual_envs\transformer-tf\lib\site-packages\torch\nn\functional.py:5476: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [00:03<00:00, 20.32it/s]
# training loss at epoch 1: 1.449725836138182
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 69.07it/s]
# validation loss at epoch 1: 1.1640504002571106
# ...

# %%
eval_config = FCPEvaluationConfig("C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/lstm_2d/wind_LSTM_repeat5_dataset.pkl",
                      "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/lstm_2d/wind_LSTM_dataset_config.pkl",
                                  "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/results/wind/lstm_2d/",
                                  1.1, 0.95, 4096, 2, 1e-05, 1e-05)

# %%
evaluate_fcp(eval_config, device="cuda")
# Out:
# use Transformer as an encoder
# computing empirical coverage by solving reverse flow ODE...
#   0%|                                                                                           | 0/46 [00:00<?, ?it/s]C:\Users\jayao\Desktop\python_projects\virtual_envs\transformer-tf\lib\site-packages\torch\nn\modules\transformer.py:685: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   return torch._transformer_encoder_layer_fwd(
# 100%|█████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 103.54it/s]
# empirical coverage: 0.95652174949646
# estimating the region size...
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 46/46 [00:48<00:00,  1.06s/it]
# base region size: 18.82274055480957
# estimated avg region size: 1.0712649822235107
# ...

# %%
fcp_config = FCPConfig("C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/loo_2d/wind_loo-bootstrap_repeat5_dataset.pkl",
                      "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/loo_2d/wind_loo-bootstrap_dataset_config.pkl",
                       "./results/wind/loo_2d/",
                      "concatlinear",
                      [32, 32, 32, 32],
                      torch.nn.Softplus(),
                      1,
                        0.05,
                      4,
                      0.0005,
                      50,
                      0,
                      False,
                      4)

# %%
encoder_config = TransformerEncoderConfig(32, 2, 128, 4, 0.1, 50)

# %%
run_fcp(fcp_config, encoder_config, device="cuda")
# Out:
# use Transformer as an encoder
# training flow...
# 100%|████████████████████████████████████████████████████████████████████████████████| 140/140 [00:04<00:00, 29.45it/s]
# training loss at epoch 1: 1.0401160393442426
# 100%|█████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 101.35it/s]
# validation loss at epoch 1: 0.9743112890343917
# 100%|████████████████████████████████████████████████████████████████████████████████| 140/140 [00:04<00:00, 33.05it/s]
# training loss at epoch 2: 0.7263798705169133
# 100%|█████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 116.48it/s]
# validation loss at epoch 2: 0.3938962974046406
# 100%|████████████████████████████████████████████████████████████████████████████████| 140/140 [00:04<00:00, 34.73it/s]
# training loss at epoch 3: 0.4040693887642452
# ...

# %%
eval_config = FCPEvaluationConfig("C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/lstm_2d/wind_LSTM_repeat5_dataset.pkl",
                      "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/lstm_2d/wind_LSTM_dataset_config.pkl",
                                  "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/results/wind/lstm_2d/",
                                  1.1, 0.95, 4096, 2, 1e-05, 1e-05)

# %%
eval_config = FCPEvaluationConfig("C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/loo_2d/wind_loo-bootstrap_repeat5_dataset.pkl",
                      "C:/Users/jayao/Desktop/python_projects/flow_conformal_prediction/data/wind/loo_2d/wind_loo-bootstrap_dataset_config.pkl",
                                  "C:/Users/jayao/Desktop/python_projects/flow_cp/results/wind/loo_2d/",
                                  1.1, 0.95, 4096, 2, 1e-05, 1e-05)

# %%
evaluate_fcp(eval_config, device="cuda")
# Out:
# use Transformer as an encoder
# computing empirical coverage by solving reverse flow ODE...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 77/77 [00:00<00:00, 158.70it/s]
# empirical coverage: 0.948051929473877
# estimating the region size...
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 77/77 [01:21<00:00,  1.06s/it]
# base region size: 18.82274055480957
# estimated avg region size: 0.9013941287994385
# use Transformer as an encoder
# computing empirical coverage by solving reverse flow ODE...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 77/77 [00:00<00:00, 164.29it/s]
# empirical coverage: 0.9610389471054077
# estimating the region size...
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 77/77 [01:22<00:00,  1.07s/it]
# base region size: 18.82274055480957
# estimated avg region size: 0.9117051959037781
# ...

# %%
summarize_fcp_results("C:/Users/jayao/Desktop/python_projects/flow_cp/results/wind/loo_2d/",
                     5, "wind", 2, 1.1)
# Out:
# avg coverage: 0.9506493330001831
# std coverage: 0.017229225851807035
# avg size: 1.0010144710540771
# std size: 0.09601176530122757
